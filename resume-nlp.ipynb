# %%
import nltk
import re
import joblib

from docx import Document

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, classification_report

import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Kavin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kavin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kavin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import docx2txt

resume_text = docx2txt.process(
    "KAVIN KUMAR ATS RESUME.docx"
)

print(resume_text)
# Out:
# +918072958428                                                                              kavinkumarscse@gmail.com
#
# LinkedIn Id:www.linkedin.com/in/kavin-kumar-s07                     GitHub :https://github.com/kavinkumar-s16
#
# +918072958428                                                                              kavinkumarscse@gmail.com
#
# LinkedIn Id:www.linkedin.com/in/kavin-kumar-s07                     GitHub :https://github.com/kavinkumar-s16KAVIN KUMAR.S
#
#
#
#
#
# Career Objective
#
#
#
# To leverage my strong foundation in software development, problem-solving,
#
# and programming to contribute effectively as a software engineer, while
#
# continuously learning and growing within a dynamic organization.
#
#
#
# Educational Qualification
#
#
#
# Under Graduation
#
# Course : B.E Computer Science and Engineering
#
# Board /University : Anna University
#
# College Name : Nehru Institute of Technology
#
# Period of Study :  2023 - 2027
#
# CGPA : 8.48
#
#
#
# 12th
#
# ...

# %%
text = resume_text.lower()

print(text)
# Out:
# +918072958428                                                                              kavinkumarscse@gmail.com
#
# linkedin id:www.linkedin.com/in/kavin-kumar-s07                     github :https://github.com/kavinkumar-s16
#
# +918072958428                                                                              kavinkumarscse@gmail.com
#
# linkedin id:www.linkedin.com/in/kavin-kumar-s07                     github :https://github.com/kavinkumar-s16kavin kumar.s
#
#
#
#
#
# career objective
#
#
#
# to leverage my strong foundation in software development, problem-solving,
#
# and programming to contribute effectively as a software engineer, while
#
# continuously learning and growing within a dynamic organization.
#
#
#
# educational qualification
#
#
#
# under graduation
#
# course : b.e computer science and engineering
#
# board /university : anna university
#
# college name : nehru institute of technology
#
# period of study :  2023 - 2027
#
# cgpa : 8.48
#
#
#
# 12th
#
# ...

# %%
clean_text = re.sub('[^a-zA-Z]', ' ', text)

print(clean_text)
# Out:
#                                                                                            kavinkumarscse gmail com   linkedin id www linkedin com in kavin kumar s                       github  https   github com kavinkumar s                                                                                               kavinkumarscse gmail com   linkedin id www linkedin com in kavin kumar s                       github  https   github com kavinkumar s  kavin kumar s                                                                                                         career objective                                                         to leverage my strong foundation in software development  problem solving    and programming to contribute effectively as a software engineer  while   continuously learning and growing within a dynamic organization     educational qualification              under graduation  course   b e computer science and engineering   board  university   anna un
# ...

# %%
tokens = word_tokenize(clean_text)

print(tokens)
# Out:
# ['kavinkumarscse', 'gmail', 'com', 'linkedin', 'id', 'www', 'linkedin', 'com', 'in', 'kavin', 'kumar', 's', 'github', 'https', 'github', 'com', 'kavinkumar', 's', 'kavinkumarscse', 'gmail', 'com', 'linkedin', 'id', 'www', 'linkedin', 'com', 'in', 'kavin', 'kumar', 's', 'github', 'https', 'github', 'com', 'kavinkumar', 's', 'kavin', 'kumar', 's', 'career', 'objective', 'to', 'leverage', 'my', 'strong', 'foundation', 'in', 'software', 'development', 'problem', 'solving', 'and', 'programming', 'to', 'contribute', 'effectively', 'as', 'a', 'software', 'engineer', 'while', 'continuously', 'learning', 'and', 'growing', 'within', 'a', 'dynamic', 'organization', 'educational', 'qualification', 'under', 'graduation', 'course', 'b', 'e', 'computer', 'science', 'and', 'engineering', 'board', 'university', 'anna', 'university', 'college', 'name', 'nehru', 'institute', 'of', 'technology', 'period', 'of', 'study', 'cgpa', 'th', 'state', 'board', 'of', 'tamil', 'nadu', 'school', 'name', 'shri', 'kr
# ...

# %%
stop_words = set(stopwords.words('english'))
filtered_words = []
for word in tokens:
    if word not in stop_words:
        filtered_words.append(word)
print(filtered_words)
# Out:
# ['kavinkumarscse', 'gmail', 'com', 'linkedin', 'id', 'www', 'linkedin', 'com', 'kavin', 'kumar', 'github', 'https', 'github', 'com', 'kavinkumar', 'kavinkumarscse', 'gmail', 'com', 'linkedin', 'id', 'www', 'linkedin', 'com', 'kavin', 'kumar', 'github', 'https', 'github', 'com', 'kavinkumar', 'kavin', 'kumar', 'career', 'objective', 'leverage', 'strong', 'foundation', 'software', 'development', 'problem', 'solving', 'programming', 'contribute', 'effectively', 'software', 'engineer', 'continuously', 'learning', 'growing', 'within', 'dynamic', 'organization', 'educational', 'qualification', 'graduation', 'course', 'b', 'e', 'computer', 'science', 'engineering', 'board', 'university', 'anna', 'university', 'college', 'name', 'nehru', 'institute', 'technology', 'period', 'study', 'cgpa', 'th', 'state', 'board', 'tamil', 'nadu', 'school', 'name', 'shri', 'krishna', 'vidhyalaya', 'matric', 'higher', 'secondary', 'school', 'pollachi', 'period', 'study', 'percentage', 'th', 'state', 'board', 
# ...

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = []
for word in filtered_words:
    lemmatized_words.append(
        lemmatizer.lemmatize(word)
    )

print(lemmatized_words)
# Out:
# ['kavinkumarscse', 'gmail', 'com', 'linkedin', 'id', 'www', 'linkedin', 'com', 'kavin', 'kumar', 'github', 'http', 'github', 'com', 'kavinkumar', 'kavinkumarscse', 'gmail', 'com', 'linkedin', 'id', 'www', 'linkedin', 'com', 'kavin', 'kumar', 'github', 'http', 'github', 'com', 'kavinkumar', 'kavin', 'kumar', 'career', 'objective', 'leverage', 'strong', 'foundation', 'software', 'development', 'problem', 'solving', 'programming', 'contribute', 'effectively', 'software', 'engineer', 'continuously', 'learning', 'growing', 'within', 'dynamic', 'organization', 'educational', 'qualification', 'graduation', 'course', 'b', 'e', 'computer', 'science', 'engineering', 'board', 'university', 'anna', 'university', 'college', 'name', 'nehru', 'institute', 'technology', 'period', 'study', 'cgpa', 'th', 'state', 'board', 'tamil', 'nadu', 'school', 'name', 'shri', 'krishna', 'vidhyalaya', 'matric', 'higher', 'secondary', 'school', 'pollachi', 'period', 'study', 'percentage', 'th', 'state', 'board', 't
# ...

# %%
processed_resume = " ".join(lemmatized_words)

print(processed_resume)
# Out:
# kavinkumarscse gmail com linkedin id www linkedin com kavin kumar github http github com kavinkumar kavinkumarscse gmail com linkedin id www linkedin com kavin kumar github http github com kavinkumar kavin kumar career objective leverage strong foundation software development problem solving programming contribute effectively software engineer continuously learning growing within dynamic organization educational qualification graduation course b e computer science engineering board university anna university college name nehru institute technology period study cgpa th state board tamil nadu school name shri krishna vidhyalaya matric higher secondary school pollachi period study percentage th state board tamil nadu school name shri krishna vidhyalaya matric higher secondary school pollachi period study percentage pas technical skill m word m excel m powerpoint c python conference title fuel revolutionizing demand fuel delivery place nehru institute engineering technology period certif
# ...

# %%
resume_data = [

# Technical Skills
"python sql machine learning pandas numpy excel power bi statistics data analysis programming",

"java c cpp python data structures algorithms database management system",

# Projects
"student performance analysis project machine learning classification prediction",

"movie recommendation system using python machine learning collaborative filtering",

# Education
"bachelor of engineering computer science engineering college university degree",

"higher secondary school computer science education academic qualification",

# Experience
"data science intern saiket systems internship machine learning project work",

"internship experience software developer trainee company professional experience",

# Certifications
"oracle cloud infrastructure ai foundations certification course certificate",

"online certification machine learning python data science course"

]


labels = [

"Technical Skills",
"Technical Skills",

"Projects",
"Projects",

"Education",
"Education",

"Experience",
"Experience",

"Certifications",
"Certifications"

]


print("Dataset updated")
# Out:
# Dataset updated

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
X = tfidf.fit_transform(resume_data)
print(X.shape)
# Out:
# (10, 64)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    labels,
    test_size=0.25,
    random_state=42
)
print("Data split completed")
# Out:
# Data split completed

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()


model.fit(
    X, labels
)
print("Naive Bayes trained successfully")
# Out:
# Naive Bayes trained successfully

# %%
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# ['Experience' 'Projects' 'Experience']

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(
    y_test,
    y_pred
)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.0

# %%
resume_vector = tfidf.transform(
    [processed_resume]
)
prediction = model.predict(
    resume_vector
)
print(
    "Predicted Resume Section:",
    prediction[0]
)
# Out:
# Predicted Resume Section: Experience

# %%
joblib.dump(
    model,
    "resume_naive_bayes_model.pkl"
)


joblib.dump(
    tfidf,
    "resume_tfidf_vectorizer.pkl"
)
# Out:
# ['resume_tfidf_vectorizer.pkl']
